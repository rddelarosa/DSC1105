# %% [markdown]
# <a href="https://colab.research.google.com/github/rddelarosa/DSC1105/blob/main/LAB_FA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(ggplot2)

# %% [markdown]
# 1. Create a histogram using the diamonds dataset.
# Start with the following example:
#
# ggplot(diamonds) + geom_histogram(aes(x = carat))
# Re-write this plot using the layer() function instead of geom_histogram(), as demonstrated in class.
# Hint: If you are unsure about default values (e.g., stat, position), inspect the plot object using p$layers.

# %%
# 1. Create a histogram of the carat variable using ggplot() and geom_histogram()
p2_adjusted <- ggplot(diamonds) +
  layer(
    geom = "bar",
    stat = "bin",
    position = "stack",
    mapping = aes(x = carat)
  )
print(p2_adjusted)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title

# %% [markdown]
# 2. Recall that a histogram is a plot that uses stat_bin rather than stat_identity.
# Modify your histogram from Question 1 so that it uses a different geom, such as geom_line() or geom_point(), while still relying on stat_bin.

# %%
# Using lines instead of bars to visualize the bins
ggplot(diamonds, aes(x = carat)) +
  geom_point(stat = "bin")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title

# %% [markdown]
# 3. Using the histogram with bars from Question 1, add an aesthetic mapping based on one of the factor variables in the dataset (e.g., cut, color, or clarity).
# Apply this mapping to either the fill or color aesthetic.

# %%
# Mapping the 'cut' variable to the 'fill' aesthetic
ggplot(diamonds, aes(x = carat, fill = cut)) +
  geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title

# %% [markdown]
# 4. What is the default position adjustment used in a histogram?
# Change the position adjustment in the histogram you created in Question 3 to a different option (hint: try "dodge"), and observe how the plot changes.

# %% [markdown]
# The default position adjustment for a histogram is "stack", which stacks the bars on top of each other.

# %%
ggplot(diamonds, aes(x = carat, fill = cut)) +
  geom_histogram(position = "dodge")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value `binwidth`.
# plot without title

# %% [markdown]
# 5. **Reflection**
# - In 3–5 sentences, reflect on this activity by answering the following:
#
# - What did you learn about how histograms are constructed in ggplot2?
#
# - Which part of the activity was most challenging, and why?
#
# - How did changing the geom, aesthetic, or position affect your understanding of the data?

# %% [markdown]
# Through this activity, I learned that functions like geom_histogram are actually specific configurations of the layer() function, utilizing geom="bar" and stat="bin". The most challenging part was Question 2, as I initially didn't realize that geom_line could accept stat="bin" to display frequency data without manual pre-calculation. Changing the position to 'dodge' in the final step clarified how stacking can sometimes obscure the distribution of individual groups, whereas side-by-side placement makes direct comparison of counts easier.
